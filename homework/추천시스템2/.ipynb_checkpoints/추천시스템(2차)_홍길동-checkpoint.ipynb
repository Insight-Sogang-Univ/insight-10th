# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Item-Based-Collaborative-Filtering" data-toc-modified-id="Item-Based-Collaborative-Filtering-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Item-Based Collaborative Filtering</a></span><ul class="toc-item"><li><span><a href="#(1)-아이템-유사도-계산" data-toc-modified-id="(1)-아이템-유사도-계산-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>(1) 아이템 유사도 계산</a></span></li><li><span><a href="#(2)-아이템-평점-예측" data-toc-modified-id="(2)-아이템-평점-예측-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>(2) 아이템 평점 예측</a></span></li><li><span><a href="#(2)-1.-평점-예측-성능-평가" data-toc-modified-id="(2)-1.-평점-예측-성능-평가-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>(2)-1. 평점 예측 성능 평가</a></span></li><li><span><a href="#(3)-치킨추천" data-toc-modified-id="(3)-치킨추천-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>(3) 치킨추천</a></span></li></ul></li><li><span><a href="#User-based-Collaborative-Filtering" data-toc-modified-id="User-based-Collaborative-Filtering-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>User-based Collaborative Filtering</a></span><ul class="toc-item"><li><span><a href="#Data-set-살펴보기" data-toc-modified-id="Data-set-살펴보기-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Data set 살펴보기</a></span></li><li><span><a href="#(1)-사용자-유사도-계산" data-toc-modified-id="(1)-사용자-유사도-계산-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>(1) 사용자 유사도 계산</a></span></li><li><span><a href="#(2)-사용자별-유사도가-높은-상위-사용자-5명-추출" data-toc-modified-id="(2)-사용자별-유사도가-높은-상위-사용자-5명-추출-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>(2) 사용자별 유사도가 높은 상위 사용자 5명 추출</a></span></li><li><span><a href="#(3)-버디조-최애-치킨-선정하기" data-toc-modified-id="(3)-버디조-최애-치킨-선정하기-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>(3) 버디조 최애 치킨 선정하기</a></span></li><li><span><a href="#사용자별-유사도를-기준으로,-예측-평가-점수-산출" data-toc-modified-id="사용자별-유사도를-기준으로,-예측-평가-점수-산출-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>사용자별 유사도를 기준으로, 예측 평가 점수 산출</a></span></li><li><span><a href="#buddy_group-데이터-추출" data-toc-modified-id="buddy_group-데이터-추출-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>buddy_group 데이터 추출</a></span></li><li><span><a href="#상위-3개-항목-도출" data-toc-modified-id="상위-3개-항목-도출-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>상위 3개 항목 도출</a></span></li></ul></li></ul></div>

# %% [markdown]
# # T/F

# %% [markdown]
# (1) 데이터가 충분한 경우 사용자 기반협업 필터링이 아이템 기반 협업 필터링보다 다소 정확하므로, 대규모 데이터를 다뤄야 하는 상업용 사이트에서도 사용자 기반협업 필터링에 기반한 알고리즘을 사용한다고 한다.<br>
#
# (2) 평갓값 행렬은 수집한 사용자의 아이템 선호도를 정성적으로 나타낸 것으로, 사용자 X 아이템으로 계산한다. 이렇게 발견된 평점은 희소 행렬의 형태를 띄고 있어 명시되지 않은 평점을 대체하는 것이 가능하다<br>
#
# (3) 차원 축소 기법은 사용자와 아이템의 상관관계를 사용해 완전한 형태로 구체화되고 축소된 표현을 만든다. <br>
#
# (4) Model based는 데이터의 규칙성을 바탕으로 미리 모델을 만들어 두기 때문에, 데이터 변화시 매번 새로 모델을 만들기에 용이하다

# %% [markdown]
# answer:

# %% [markdown]
# # 주관식 문제

# %% [markdown]
# (단답형) 사용자간 유사도 계산에서 어떤 것을 도출한 값으로 사용자간 유사도를 계산하나요?

# %% [markdown]
# answer:

# %% [markdown]
# (서술형) 연관 분석의 세 지표(지지도, 신뢰도, 향상도)를 계산하는 식을 정리해봅시다. 그리고 연관 분석 규칙 생성시 규칙 수가 기하급수적으로 증가하는 문제점을 해결하는 알고리즘의 이름과 장단점은 무엇인가요?

# %% [markdown]
# answer:

# %% [markdown]
# (서술형) Memory based의 장점과 단점에 대해 간단히 서술하시오.

# %% [markdown]
# answer:

# %% [markdown]
# ## Item-Based Collaborative Filtering

# %% [markdown]
# 컨텐츠 기반 필터링은 '나'의 input 데이터들을 바탕으로 추천해주는 단순한 방식이며, Item-Based 협업 필터링은 Item의 평점 분포를 행렬화하여 추천해주는 것으로, 비교적 정확도가 높다.

# %%
import pandas as pd
import numpy as np

# %%
ratings=pd.read_csv("./chicken.csv", index_col='이름')
ratings
# Out:
#      (BHC) 뿌링클  (BHC) 맛초킹  (BHC) 레드킹  (교촌) 교촌콤보  (교촌) 허니콤보  (교촌) 레드콤보  \
# 이름
# 김하나          3          0          0          4          3          2
# 박세훈          3          1          0          5          5          0
# 김민서          3          3          1          4          3          2
# 문지환          5          4          4          1          5          5
# 최진호          4          2          0          3          5          0
# 이승연          2          0          0          3          4          3
# 김유진          5          0          4          2          5          3
# 나하영          2          3          2          1          3          1
# 김동영          4          0          0          4          3          0
# 조강석          1          1          0          3          2          1
# 임채홍          5          3          3          3          5          5
# 김승현          3          3          2          2          1          1
# 서지윤          4          0          0          0          5          0
# 김은채          5          4          3          0          5          4
# 이민혜          5          3          2          1          4          5
# 임정연          5          3          1          2          5          1
# 박수빈          4          0          0          3          5          0
# 송상훈          3          0          3          4          4          4
# 국필호          3          4          2          0          5          3
# 신동현          5          4          4          4          5          4
# 노유정          5          0          0          4          4          4
# 김보미          1          0          0          1          2          0
# 이경연          3          0          0          4          5          4
# 김선웅          3          2          2          5          4          5
# 권범윤          3          0          0          5          2          3
# 이유선          5          0          0          4          5          4
# 이건화          5          3          3          5          5          3
# 정희수          4          0          0          4          5          5
# 허진           5          2          0          0          5          4
# 이재윤          2          0          0          3          3          0
#
#      (굽네) 고추바사삭  (굽네) 볼케이노  (굽네) 갈비천왕  (BBQ) 황금올리브  ...  (60계) 간지치킨  \
# 이름                                                  ...
# 김하나           5          0          5            5  ...           0
# 박세훈           2          0          1            5  ...           0
# 김민서           4          2          3            5  ...           0
# 문지환           4          5          4            5  ...           0
# 최진호           5          0          0            5  ...           0
# 이승연           5          4          4            4  ...           0
# 김유진           2          0          2            5  ...           0
# 나하영           3          2          0            1  ...           3
# 김동영           4          0          0            5  ...           0
# 조강석           3          0          0            3  ...           0
# 임채홍           5          3          1            2  ...           0
# 김승현           2          1          1            2  ...           0
# 서지윤           4          0          3            3  ...           0
# 김은채           3          0          3            3  ...           0
# 이민혜           5          3          2            5  ...           3
# 임정연           5          0          1            4  ...           0
# 박수빈           0          0          0            5  ...           0
# 송상훈           4          0          0            4  ...           0
# 국필호           5          3          0            5  ...           0
# 신동현           5          5          5            5  ...           0
# 노유정           4          3          3            5  ...           0
# 김보미           3          3          0            5  ...           0
# 이경연           5          4          2            4  ...           0
# 김선웅           0          0          0            5  ...           0
# 권범윤           5          2          1            5  ...           4
# 이유선           5          3          0            5  ...           0
# 이건화           3          4          5            5  ...           3
# 정희수           5          5          3            4  ...           0
# 허진            2          2          1            5  ...           5
# 이재윤           3          2          0            3  ...           0
#
#      (바른치킨) 대세레드  (바른치킨) 현미바사삭  (바른치킨) 통곡물간장  (노랑통닭) 알싸한마늘치킨  (노랑통닭) 뿌리노랑치킨  \
# 이름
# 김하나            3             5             5               5              0
# 박세훈            0             4             0               4              4
# 김민서            1             3             4               4              0
# 문지환            0             0             3               0              3
# 최진호            1             3             4               4              3
# 이승연            0             0             0               0              0
# 김유진            0             0             0               3              3
# 나하영            3             2             0               2              0
# 김동영            0             0             0               0              0
# 조강석            0             2             2               3              1
# 임채홍            0             0             0               3              0
# 김승현            3             2             2               3              2
# 서지윤            0             0             0               0              0
# 김은채            0             0             0               4              0
# 이민혜            5             4             5               0              0
# 임정연            0             2             2               2              1
# 박수빈            0             0             4               0              0
# 송상훈            0             0             0               4              0
# 국필호            0             4             0               4              0
# 신동현            0             5             0               0              0
# 노유정            0             0             0               4              0
# 김보미            0             0             0               1              0
# 이경연            0             0             0               0              4
# 김선웅            0             4             0               0              0
# 권범윤            2             4             4               0              0
# 이유선            0             0             0               0              0
# 이건화            3             3             3               3              3
# 정희수            0             3             0               4              0
# 허진             0             0             5               3              0
# 이재윤            0             0             0               3              3
#
#      (노랑통닭) 칼칼한청양치킨  (푸라닭) 블랙알리오  (푸라닭) 청양마요  (푸라닭) 콘소메이징
# 이름
# 김하나               0            4           0            0
# 박세훈               1            1           5            0
# 김민서               1            5           4            4
# 문지환               4            4           4            0
# 최진호               0            4           3            2
# 이승연               0            3           4            0
# 김유진               0            5           5            3
# 나하영               0            2           3            3
# 김동영               0            0           0            0
# 조강석               0            3           2            1
# 임채홍               0            0           0            0
# 김승현               0            3           1            2
# 서지윤               0            4           0            5
# 김은채               0            3           4            3
# 이민혜               0            3           4            5
# 임정연               0            5           2            2
# 박수빈               0            4           4            0
# 송상훈               0            4           4            0
# 국필호               3            3           4            0
# 신동현               0            5           5            5
# 노유정               0            3           3            5
# 김보미               0            1           1            0
# 이경연               0            0           0            0
# 김선웅               0            5           5            5
# 권범윤               0            4           4            4
# 이유선               0            3           0            4
# 이건화               3            4           4            3
# 정희수               3            4           2            2
# 허진                0            4           4            4
# 이재윤               0            2           0            1
#
# [30 rows x 30 columns]

# %% [markdown]
# ### (1) 아이템 유사도 계산

# %%
from sklearn.metrics.pairwise import cosine_similarity
# 유사도 계산을 위해 결측치를 0으로 대체
ratings.******(0, inplace=True)

# 유사도 계산
item_similarity = ******_similarity(ratings.T)

# 아이템 유사도 DataFrame 생성
item_similarity = pd.DataFrame(data=item_similarity,
                              index=ratings.T.index,
                              columns=ratings.T.index)
item_similarity.head()
# Out:
#            (BHC) 뿌링클  (BHC) 맛초킹  (BHC) 레드킹  (교촌) 교촌콤보  (교촌) 허니콤보  (교촌) 레드콤보  \
# (BHC) 뿌링클   1.000000   0.730469   0.705118   0.806068   0.969440   0.855028
# (BHC) 맛초킹   0.730469   1.000000   0.801611   0.465749   0.700740   0.672880
# (BHC) 레드킹   0.705118   0.801611   1.000000   0.482353   0.665814   0.730740
# (교촌) 교촌콤보   0.806068   0.465749   0.482353   1.000000   0.817492   0.720785
# (교촌) 허니콤보   0.969440   0.700740   0.665814   0.817492   1.000000   0.837297
#
#            (굽네) 고추바사삭  (굽네) 볼케이노  (굽네) 갈비천왕  (BBQ) 황금올리브  ...  (60계) 간지치킨  \
# (BHC) 뿌링클    0.897517   0.720277   0.744795     0.937731  ...    0.417313
# (BHC) 맛초킹    0.655400   0.604476   0.581311     0.639187  ...    0.377866
# (BHC) 레드킹    0.575923   0.559113   0.603403     0.595430  ...    0.247350
# (교촌) 교촌콤보    0.810408   0.641686   0.640579     0.875476  ...    0.280585
# (교촌) 허니콤보    0.904720   0.732275   0.720843     0.947514  ...    0.360748
#
#            (바른치킨) 대세레드  (바른치킨) 현미바사삭  (바른치킨) 통곡물간장  (노랑통닭) 알싸한마늘치킨  \
# (BHC) 뿌링클     0.443452      0.621982      0.612826        0.716535
# (BHC) 맛초킹     0.483561      0.649214      0.518247        0.583892
# (BHC) 레드킹     0.379717      0.475177      0.306329        0.505069
# (교촌) 교촌콤보     0.399876      0.702763      0.507899        0.665913
# (교촌) 허니콤보     0.358163      0.626368      0.550521        0.732922
#
#            (노랑통닭) 뿌리노랑치킨  (노랑통닭) 칼칼한청양치킨  (푸라닭) 블랙알리오  (푸라닭) 청양마요  (푸라닭) 콘소메이징
# (BHC) 뿌링클       0.512259        0.435692     0.895699    0.818131     0.786256
# (BHC) 맛초킹       0.378997        0.514716     0.685776    0.723689     0.605070
# (BHC) 레드킹       0.405127        0.463330     0.664179    0.720098     0.535849
# (교촌) 교촌콤보       0.538909        0.336503     0.783581    0.725840     0.629914
# (교촌) 허니콤보       0.558408        0.469165     0.888941    0.837829     0.721849
#
# [5 rows x 30 columns]

# %% [markdown]
# 요기요나 배달의 민족 마케팅팀 : 유사한 선호도를 가진 치킨끼리 묶어서 할인행사를 해보고 싶다!
# -> 탑 3를 묶어보자!

# %%
def get_similar_item(title):
    return item_similarity[title].sort_values(ascending=False)[1:6]

get_similar_item("(BHC) 뿌링클").head(3)
# Out:
# (교촌) 허니콤보      0.969440
# (BBQ) 황금올리브    0.937731
# (굽네) 고추바사삭     0.897517
# Name: (BHC) 뿌링클, dtype: float64

# %%
import pandas as pd

# 치킨 리스트
chicken_list = list(item_similarity.index)

# 새로운 데이터프레임을 만들기 위한 빈 리스트 초기화
recommendations = []

# 각 치킨에 대해 유사한 항목 찾기
for chicken in chicken_list:
    similar_items = get_similar_item(chicken).head(3)
    
    # '추천 치킨'이라는 새로운 칼럼을 만들어 데이터프레임에 추가
    recommendations.append({
        'Chicken': chicken,
        'Recommendations': ', '.join(similar_items.index)
    })

# 결과 데이터프레임 생성
result_df = pd.*********(recommendations)

# 결과 출력
result_df
# Out:
#            Chicken                          Recommendations
# 0        (BHC) 뿌링클       (교촌) 허니콤보, (BBQ) 황금올리브, (굽네) 고추바사삭
# 1        (BHC) 맛초킹       (BHC) 레드킹, (BBQ) 핫황금올리브, (BHC) 뿌링클
# 2        (BHC) 레드킹         (BHC) 맛초킹, (교촌) 레드콤보, (푸라닭) 청양마요
# 3        (교촌) 교촌콤보       (BBQ) 황금올리브, (교촌) 허니콤보, (굽네) 고추바사삭
# 4        (교촌) 허니콤보       (BHC) 뿌링클, (BBQ) 황금올리브, (굽네) 고추바사삭
# 5        (교촌) 레드콤보         (BHC) 뿌링클, (교촌) 허니콤보, (굽네) 고추바사삭
# 6       (굽네) 고추바사삭        (교촌) 허니콤보, (BBQ) 황금올리브, (BHC) 뿌링클
# 7        (굽네) 볼케이노      (BBQ) 핫황금올리브, (교촌) 레드콤보, (굽네) 고추바사삭
# 8        (굽네) 갈비천왕       (BHC) 뿌링클, (푸라닭) 블랙알리오, (굽네) 고추바사삭
# 9      (BBQ) 황금올리브        (교촌) 허니콤보, (BHC) 뿌링클, (푸라닭) 블랙알리오
# 10    (BBQ) 핫황금올리브          (굽네) 볼케이노, (BHC) 맛초킹, (교촌) 레드콤보
# 11   (BBQ) 자메이카통다리      (BHC) 뿌링클, (푸라닭) 블랙알리오, (BBQ) 황금올리브
# 12     (네네) 오리엔탈파닭      (바른치킨) 통곡물간장, (네네) 스노윙, (푸라닭) 블랙알리오
# 13       (네네) 청양마요      (네네) 스노윙, (네네) 오리엔탈파닭, (바른치킨) 현미바사삭
# 14        (네네) 스노윙        (BHC) 뿌링클, (교촌) 허니콤보, (BBQ) 황금올리브
# 15      (처갓집) 블랙라벨        (굽네) 갈비천왕, (굽네) 볼케이노, (네네) 오리엔탈파닭
# 16    (처갓집) XO양념치킨      (60계) 하하핫치킨, (굽네) 볼케이노, (BBQ) 황금올리브
# 17    (처갓집) 트러플슈프림       (푸라닭) 콘소메이징, (BHC) 뿌링클, (굽네) 고추바사삭
# 18     (60계) 크크크치킨          (네네) 스노윙, (60계) 간지치킨, (BHC) 뿌링클
# 19     (60계) 하하핫치킨  (노랑통닭) 칼칼한청양치킨, (굽네) 갈비천왕, (BBQ) 핫황금올리브
# 20      (60계) 간지치킨   (60계) 크크크치킨, (바른치킨) 대세레드, (바른치킨) 통곡물간장
# 21     (바른치킨) 대세레드   (바른치킨) 통곡물간장, (바른치킨) 현미바사삭, (60계) 간지치킨
# 22    (바른치킨) 현미바사삭    (BBQ) 자메이카통다리, (푸라닭) 블랙알리오, (교촌) 교촌콤보
# 23    (바른치킨) 통곡물간장    (네네) 오리엔탈파닭, (푸라닭) 블랙알리오, (바른치킨) 대세레드
# 24  (노랑통닭) 알싸한마늘치킨      (교촌) 허니콤보, (BBQ) 황금올리브, (푸라닭) 블랙알리오
# 25   (노랑통닭) 뿌리노랑치킨        (교촌) 허니콤보, (교촌) 교촌콤보, (BBQ) 황금올리브
# 26  (노랑통닭) 칼칼한청양치킨     (60계) 하하핫치킨, (굽네) 볼케이노, (BBQ) 핫황금올리브
# 27     (푸라닭) 블랙알리오        (BBQ) 황금올리브, (BHC) 뿌링클, (교촌) 허니콤보
# 28      (푸라닭) 청양마요      (푸라닭) 블랙알리오, (BBQ) 황금올리브, (교촌) 허니콤보
# 29     (푸라닭) 콘소메이징      (푸라닭) 블랙알리오, (BHC) 뿌링클, (BBQ) 황금올리브

# %% [markdown]
# ### (2) 아이템 평점 예측

# %%
# 아이템별 평점 예측 함수
import numpy as np

def predict_rating(ratings, item_similarity):
    sum_sr = ratings @ item_similarity
    sum_s_abs = np.array([np.abs(item_similarity).sum(axis=1)])
    ratings_pred =  sum_sr / sum_s_abs
    return ratings_pred

# 아이템별 평점 예측
ratings_pred = predict_rating(ratings.values, item_similarity.values) 

# 예측한 평점에 대한 DataFrame 생성
ratings_pred_matrix = pd.DataFrame(data=ratings_pred,
                                   index= ratings.*****,
                                   columns = ratings.*******)
ratings_pred_matrix.head(5)
# Out:
#      (BHC) 뿌링클  (BHC) 맛초킹  (BHC) 레드킹  (교촌) 교촌콤보  (교촌) 허니콤보  (교촌) 레드콤보  \
# 이름
# 김하나   2.426556   2.240296   2.191914   2.543379   2.430965   2.352669
# 박세훈   2.057307   1.893531   1.900665   2.182479   2.115665   1.984928
# 김민서   3.125518   3.020473   2.941013   3.151467   3.138418   3.089764
# 문지환   2.725111   2.726690   2.876512   2.634896   2.765644   2.789140
# 최진호   2.163532   1.980516   1.958453   2.232458   2.186993   2.058614
#
#      (굽네) 고추바사삭  (굽네) 볼케이노  (굽네) 갈비천왕  (BBQ) 황금올리브  ...  (60계) 간지치킨  \
# 이름                                                  ...
# 김하나    2.496446   2.262058   2.466558     2.475892  ...    2.188724
# 박세훈    2.065042   1.911015   1.937837     2.109234  ...    1.683724
# 김민서    3.143506   3.013248   3.042969     3.155769  ...    2.964933
# 문지환    2.728890   2.840501   2.772928     2.709986  ...    2.255980
# 최진호    2.200035   1.911160   1.993615     2.201657  ...    1.865657
#
#      (바른치킨) 대세레드  (바른치킨) 현미바사삭  (바른치킨) 통곡물간장  (노랑통닭) 알싸한마늘치킨  (노랑통닭) 뿌리노랑치킨  \
# 이름
# 김하나     2.420471      2.554594      2.552435        2.584723       2.347621
# 박세훈     1.719684      2.065708      1.911332        2.188537       2.281492
# 김민서     2.933791      3.065754      3.119450        3.194310       2.887230
# 문지환     2.243923      2.512151      2.466402        2.643975       2.857745
# 최진호     1.965882      2.145528      2.095779        2.305232       2.239809
#
#      (노랑통닭) 칼칼한청양치킨  (푸라닭) 블랙알리오  (푸라닭) 청양마요  (푸라닭) 콘소메이징
# 이름
# 김하나        2.138470     2.478074    2.363987     2.361792
# 박세훈        1.940953     2.055897    2.078991     1.920529
# 김민서        2.896989     3.154716    3.106008     3.151205
# 문지환        3.067012     2.689349    2.714446     2.500316
# 최진호        1.759584     2.180219    2.139522     2.131738
#
# [5 rows x 30 columns]

# %% [markdown]
# ### (2)-1. 평점 예측 성능 평가

# %%
# 평점 예측 성능 평가 함수 (MSE)
from sklearn.metrics import mean_squared_error

def get_mse(pred, actual):
    pred = pred[actual.nonzero()].flatten()
    actual = actual[actual.nonzero()].flatten()
    return mean_squared_error(pred, actual)

MSE = get_***(ratings_pred, ratings.values)
print(f'아이템 기반 모든 인접 이웃 MSE: {MSE:.4f}')
# Out:
# 아이템 기반 모든 인접 이웃 MSE: 2.6413

# %%
# 평점 예측 성능 평가 함수 (RMSE)
from sklearn.metrics import mean_squared_error

def get_rmse(pred, actual):
    pred = pred[actual.nonzero()].flatten()
    actual = actual[actual.nonzero()].flatten()
    return mean_squared_error(pred, actual, squared=False)
#squared=False 하면 RMSE, 안하면 MSE

RMSE = get_****(ratings_pred, ratings.values)
print(f'아이템 기반 모든 인접 이웃 RMSE: {RMSE:.4f}')
# Out:
# 아이템 기반 모든 인접 이웃 RMSE: 1.6252

# %%
# 평점 예측 성능 평가 함수 (MAE)
from sklearn.metrics import median_absolute_error

def get_mae(pred, actual):
    pred=pred[actual.nonzero()].flatten()
    actual=actual[actual.nonzero()].flatten()
    return median_absolute_error(pred, actual)

MAE=get_***(ratings_pred, ratings.values)
print(f'아이템 기반 모든 인접 이웃 MAE: {MAE:.4f}')
# Out:
# 아이템 기반 모든 인접 이웃 MAE: 1.2799

# %% [markdown]
# ### (3) 치킨추천
# 본인에게 치킨을 추천해볼까요? -> ****에 "최진호"와 같이 입력해주세요!
#
#
# 만약 본인이 모든 치킨을 다 평가했다면 "최진호"로 과제 진행해주세요!

# %%
# 본인이 높은 평점을 준 치킨
user_rated_food = ratings.loc[*****, :]
user_rated_food[user_rated_food > 0].sort_values(ascending=False)[:5]
# Out:
# (교촌) 허니콤보        5
# (굽네) 고추바사삭       5
# (BBQ) 황금올리브      5
# (BHC) 뿌링클        4
# (BBQ) 자메이카통다리    4
# Name: 최진호, dtype: int64

# %%
# 본인이 평가하지 않은 치킨

def never_try_food(ratings, userId):
    user_rating = ratings.loc[userId,:]
    never_food_list = user_rating[user_rating == 0].index.tolist()
    food_list = ratings.columns.tolist()
    never_list = [food for food in food_list if food in never_food_list]
    return never_list

unrated_food = never_try_food(ratings, *****)
print(unrated_food)
# Out:
# ['(BHC) 레드킹', '(교촌) 레드콤보', '(굽네) 볼케이노', '(굽네) 갈비천왕', '(BBQ) 핫황금올리브', '(네네) 오리엔탈파닭', '(네네) 청양마요', '(네네) 스노윙', '(처갓집) 블랙라벨', '(처갓집) XO양념치킨', '(60계) 크크크치킨', '(60계) 하하핫치킨', '(60계) 간지치킨', '(노랑통닭) 칼칼한청양치킨']

# %%
# 본인이 평가하지 않은 치킨에 대해 직접 예측한 평점을 바탕으로 음식 추천!

def recomm_food_by_userid(pred_df, userId, never_list, top_n=10):  
    recomm_food = pred_df.loc[userId, never_list].sort_values(ascending=False)[:top_n]
    return recomm_food

recommend_food = recomm_food_by_userid(ratings_pred_matrix, *****, unrated_food, top_n=5)
recommend_food
# Out:
# (교촌) 레드콤보      2.058614
# (네네) 스노윙       2.037856
# (굽네) 갈비천왕      1.993615
# (60계) 크크크치킨    1.969099
# (네네) 오리엔탈파닭    1.965571
# Name: 최진호, dtype: float64

# %%
name = list(ratings.index)
best_recommend=[]
best_score =[]
for word in name:
    user_rated_food = ratings.loc[word, :]
    user_rated_food[user_rated_food > 0].sort_values(ascending=False)[:5]
    unrated_food = never_try_food(ratings, word)
    best_recommend.append(list(recomm_food_by_userid(ratings_pred_matrix, word, unrated_food, top_n=1).index))    
    best_score.append(list(recomm_food_by_userid(ratings_pred_matrix, word, unrated_food, top_n=1).values))    
    
present1 = pd.DataFrame({'이름':name,'추천치킨_Item':best_recommend,'평점_Item':best_score})
present1
# Out:
#      이름         추천치킨_Item               평점_Item
# 0   김하나       [(네네) 청양마요]   [2.374277231944715]
# 1   박세훈       [(교촌) 레드콤보]  [1.9849277539377395]
# 2   김민서       [(네네) 청양마요]   [2.984994658015867]
# 3   문지환  [(노랑통닭) 알싸한마늘치킨]  [2.6439752144912436]
# 4   최진호       [(교촌) 레드콤보]  [2.0586135323647037]
# 5   이승연  [(노랑통닭) 알싸한마늘치킨]  [1.5886229207286953]
# 6   김유진   [(BBQ) 자메이카통다리]   [1.745180952174511]
# 7   나하영   [(BBQ) 자메이카통다리]     [1.5620578210012]
# 8   김동영   [(노랑통닭) 뿌리노랑치킨]  [0.9692718060636247]
# 9   조강석   [(BBQ) 자메이카통다리]  [1.3455514174783425]
# 10  임채홍     [(푸라닭) 블랙알리오]  [1.8098448583376991]
# 11  김승현    [(처갓집) 트러플슈프림]  [1.5853425453694254]
# 12  서지윤       [(교촌) 교촌콤보]  [1.2681505541937161]
# 13  김은채       [(교촌) 교촌콤보]   [2.196766554802298]
# 14  이민혜  [(노랑통닭) 알싸한마늘치킨]  [3.2017969643759394]
# 15  임정연    [(처갓집) 트러플슈프림]     [2.1524993880556]
# 16  박수빈    [(바른치킨) 현미바사삭]  [1.6715588466448466]
# 17  송상훈     [(푸라닭) 콘소메이징]  [1.7351722103731744]
# 18  국필호   [(노랑통닭) 뿌리노랑치킨]  [1.9915326006287166]
# 19  신동현  [(노랑통닭) 알싸한마늘치킨]  [3.4775706205787533]
# 20  노유정        [(네네) 스노윙]  [2.1389656298594417]
# 21  김보미       [(교촌) 레드콤보]   [0.826815114149258]
# 22  이경연  [(노랑통닭) 알싸한마늘치킨]  [1.6750114359280766]
# 23  김선웅      [(굽네) 고추바사삭]   [2.006491556539232]
# 24  권범윤  [(노랑통닭) 알싸한마늘치킨]  [2.1839978733385137]
# 25  이유선  [(노랑통닭) 알싸한마늘치킨]   [2.078394731141853]
# 26  이건화                []                    []
# 27  정희수   [(노랑통닭) 뿌리노랑치킨]  [2.5693964722790343]
# 28   허진       [(교촌) 교촌콤보]  [2.6880865605965507]
# 29  이재윤       [(교촌) 레드콤보]  [1.1628444184647477]

# %% [markdown]
# ## User-based Collaborative Filtering

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### Data set 살펴보기

# %%
ratings = pd.read_csv("./chicken.csv",index_col='이름')
ratings.head()
# Out:
#      (BHC) 뿌링클  (BHC) 맛초킹  (BHC) 레드킹  (교촌) 교촌콤보  (교촌) 허니콤보  (교촌) 레드콤보  \
# 이름
# 김하나          3          0          0          4          3          2
# 박세훈          3          1          0          5          5          0
# 김민서          3          3          1          4          3          2
# 문지환          5          4          4          1          5          5
# 최진호          4          2          0          3          5          0
#
#      (굽네) 고추바사삭  (굽네) 볼케이노  (굽네) 갈비천왕  (BBQ) 황금올리브  ...  (60계) 간지치킨  \
# 이름                                                  ...
# 김하나           5          0          5            5  ...           0
# 박세훈           2          0          1            5  ...           0
# 김민서           4          2          3            5  ...           0
# 문지환           4          5          4            5  ...           0
# 최진호           5          0          0            5  ...           0
#
#      (바른치킨) 대세레드  (바른치킨) 현미바사삭  (바른치킨) 통곡물간장  (노랑통닭) 알싸한마늘치킨  (노랑통닭) 뿌리노랑치킨  \
# 이름
# 김하나            3             5             5               5              0
# 박세훈            0             4             0               4              4
# 김민서            1             3             4               4              0
# 문지환            0             0             3               0              3
# 최진호            1             3             4               4              3
#
#      (노랑통닭) 칼칼한청양치킨  (푸라닭) 블랙알리오  (푸라닭) 청양마요  (푸라닭) 콘소메이징
# 이름
# 김하나               0            4           0            0
# 박세훈               1            1           5            0
# 김민서               1            5           4            4
# 문지환               4            4           4            0
# 최진호               0            4           3            2
#
# [5 rows x 30 columns]

# %% [markdown]
# ### (1) 사용자 유사도 계산

# %%
# 유사도 계산하기 (경험 없음은 0으로 대체 되어 있음)
user_similarity = ********(ratings)

# 사용자 유사도 DataFrame 생성
user_similarity = pd.DataFrame(data=user_similarity,
                              index=ratings.index,
                              columns=ratings.index)
user_similarity.head()
# Out:
# 이름        김하나       박세훈       김민서       문지환       최진호       이승연       김유진  \
# 이름
# 김하나  1.000000  0.699655  0.782228  0.599217  0.771490  0.575413  0.546898
# 박세훈  0.699655  1.000000  0.740900  0.611413  0.765980  0.627762  0.690919
# 김민서  0.782228  0.740900  1.000000  0.707668  0.735244  0.657351  0.625599
# 문지환  0.599217  0.611413  0.707668  1.000000  0.579674  0.792366  0.714717
# 최진호  0.771490  0.765980  0.735244  0.579674  1.000000  0.585002  0.732494
#
# 이름        나하영       김동영       조강석  ...       노유정       김보미       이경연  \
# 이름                                 ...
# 김하나  0.530940  0.521205  0.786373  ...  0.680719  0.428412  0.562699
# 박세훈  0.575481  0.590057  0.770913  ...  0.646708  0.473076  0.647562
# 김민서  0.763928  0.502806  0.801310  ...  0.713057  0.559174  0.570836
# 문지환  0.612104  0.476309  0.577851  ...  0.600345  0.491912  0.627274
# 최진호  0.654729  0.627675  0.852013  ...  0.804084  0.527274  0.615787
#
# 이름        김선웅       권범윤       이유선       이건화       정희수        허진       이재윤
# 이름
# 김하나  0.534299  0.724394  0.531335  0.766597  0.748743  0.643788  0.591301
# 박세훈  0.682971  0.658462  0.558481  0.775698  0.768108  0.641999  0.686147
# 김민서  0.671791  0.739163  0.745686  0.892203  0.799199  0.817077  0.625303
# 문지환  0.570862  0.557915  0.598689  0.795629  0.742011  0.681561  0.638161
# 최진호  0.660467  0.763215  0.617850  0.746697  0.669736  0.647184  0.670751
#
# [5 rows x 30 columns]

# %% [markdown]
# ### (2) 사용자별 유사도가 높은 상위 사용자 5명 추출

# %%
def find_n_neighbors(n):
    user_neighbor = user_similarity.apply(lambda x: pd.Series(x.sort_values(ascending=False).iloc[1:n+1].index, 
                                                index=['top{}'.format(i) for i in range(1, n+1)]), axis=1)
    return user_neighbor

user_neighbor = find_n_neighbors(5)
user_neighbor.head()
# Out:
#     top1 top2 top3 top4 top5
# 이름
# 김하나  조강석  김민서  최진호  임정연  이건화
# 박세훈  이건화  조강석  정희수  최진호  임정연
# 김민서  이건화   허진  이민혜  조강석  정희수
# 문지환  이건화  이승연  국필호  신동현  정희수
# 최진호  조강석  임정연  노유정  김하나  박세훈

# %% [markdown]
# ### (3) 버디조 최애 치킨 선정하기
# 버디조 회식 때 어떤 치킨을 먹는 것이 좋을까?

# %%
# 버디조 이름 입력
buddy_group = input("버디조의 이름을 입력하세요. (콤마로 구분): ")
buddy_group = buddy_group.******(',')
# Out:
# 버디조의 이름을 입력하세요. (콤마로 구분): 김유진,박세훈,송상훈,허진

# %% [markdown]
# ### 사용자별 유사도를 기준으로, 예측 평가 점수 산출

# %%
def predict_ratings_all_users(user_neighbor, ratings):
    predict_ratings_all = pd.DataFrame(index=ratings.index, columns=ratings.columns)

    for user in ratings.index:
        for item in ratings.columns:
            if ratings.loc[user, item] == 0:
                neighbor_ratings = ratings.loc[user_neighbor.loc[user], item]
                predict_ratings_all.loc[user, item] = np.dot(neighbor_ratings, user_similarity.loc[user, user_neighbor.loc[user]]) / sum(np.abs(user_similarity.loc[user, user_neighbor.loc[user]]))
            else:
                predict_ratings_all.loc[user, item] = ratings.loc[user, item]

    return predict_ratings_all

# 유사도 상위 5명 기준으로 계산
user_neighbor = find_n_neighbors(5)
predicted_ratings_all = predict_ratings_all_users(user_neighbor, ratings)
ratings_predicted_all = ratings.where(ratings != 0, predicted_ratings_all)
ratings_predicted_all.head()
# Out:
#      (BHC) 뿌링클 (BHC) 맛초킹 (BHC) 레드킹 (교촌) 교촌콤보  (교촌) 허니콤보 (교촌) 레드콤보 (굽네) 고추바사삭  \
# 이름
# 김하나          3  2.394996  0.993633         4          3         2          5
# 박세훈          3         1  0.803063         5          5  2.008156          2
# 김민서          3         3         1         4          3         2          4
# 문지환          5         4         4         1          5         5          4
# 최진호          4         2  0.206106         3          5  1.601035          5
#
#     (굽네) 볼케이노 (굽네) 갈비천왕  (BBQ) 황금올리브  ... (60계) 간지치킨 (바른치킨) 대세레드 (바른치킨) 현미바사삭  \
# 이름                                    ...
# 김하나  1.195136         5            5  ...   0.593534           3            5
# 박세훈  1.814472         1            5  ...    0.60813      0.8083            4
# 김민서         2         3            5  ...   2.232347           1            3
# 문지환         5         4            5  ...   0.612206    0.612206     2.992104
# 최진호  0.599666  1.955117            5  ...        0.0           1            3
#
#     (바른치킨) 통곡물간장 (노랑통닭) 알싸한마늘치킨 (노랑통닭) 뿌리노랑치킨 (노랑통닭) 칼칼한청양치킨 (푸라닭) 블랙알리오  \
# 이름
# 김하나            5              5      1.592025       0.795413           4
# 박세훈     2.201598              4             4              1           1
# 김민서            4              4      0.842917              1           5
# 문지환            3       2.185335             3              4           4
# 최진호            4              4             3       0.190416           4
#
#     (푸라닭) 청양마요 (푸라닭) 콘소메이징
# 이름
# 김하나   2.998554    2.398654
# 박세훈          5     2.00125
# 김민서          4           4
# 문지환          4    1.989924
# 최진호          3           2
#
# [5 rows x 30 columns]

# %% [markdown]
# ### buddy_group 데이터 추출

# %%
# buddy_group의 구성원들의 예측 평가 점수를 추출
buddy_group_ratings_predicted_all = ratings_predicted_all.loc[buddy_group]

# 각 열의 평균을 구해 새로운 행으로 추가
average_ratings_predicted_all = buddy_group_ratings_predicted_all.mean()
average_ratings_predicted_all = pd.DataFrame(average_ratings_predicted_all, columns=['평균 평가 점수']).transpose()

# 기존 데이터프레임에 추가
result_with_average = pd.concat([average_ratings_predicted_all, buddy_group_ratings_predicted_all])
result_with_average.head(len(buddy_group)+1)
# Out:
#           (BHC) 뿌링클 (BHC) 맛초킹 (BHC) 레드킹 (교촌) 교촌콤보  (교촌) 허니콤보 (교촌) 레드콤보  \
# 평균 평가 점수        4.0  1.536512  2.446867   3.35696       4.75  3.252039
# 김유진             5.0  1.575388         4         2       5.00         3
# 박세훈             3.0         1  0.803063         5       5.00  2.008156
# 송상훈             3.0   1.57066         3         4       4.00         4
# 허진              5.0         2  1.984406   2.42784       5.00         4
#
#          (굽네) 고추바사삭 (굽네) 볼케이노 (굽네) 갈비천왕  (BBQ) 황금올리브  ... (60계) 간지치킨  \
# 평균 평가 점수        2.5  1.390192  1.450053         4.75  ...   1.402032
# 김유진               2  0.591017         2         5.00  ...        0.0
# 박세훈               2  1.814472         1         5.00  ...    0.60813
# 송상훈               4   1.15528  1.800214         4.00  ...        0.0
# 허진                2         2         1         5.00  ...          5
#
#          (바른치킨) 대세레드 (바른치킨) 현미바사삭 (바른치킨) 통곡물간장 (노랑통닭) 알싸한마늘치킨 (노랑통닭) 뿌리노랑치킨  \
# 평균 평가 점수    0.704552      2.05307     2.089793            3.5      2.160179
# 김유진         0.187686     1.373969     0.750744              3             3
# 박세훈           0.8083            4     2.201598              4             4
# 송상훈              0.0     0.406831     0.406831              4      0.837795
# 허진          1.822223     2.431481            5              3      0.802922
#
#          (노랑통닭) 칼칼한청양치킨 (푸라닭) 블랙알리오 (푸라닭) 청양마요 (푸라닭) 콘소메이징
# 평균 평가 점수       0.451595         3.5        4.5    2.854852
# 김유진                 0.0           5          5           3
# 박세훈                   1           1          5     2.00125
# 송상훈                 0.0           4          4    2.418156
# 허진              0.80638           4          4           4
#
# [5 rows x 30 columns]

# %% [markdown]
# ### 상위 3개 항목 도출

# %%
#'평균 평가 점수'를 기준으로 내림차순 정렬하여 상위 3개 항목 선택
buddy_group_top3 = result_with_average.sort_values(by='평균 평가 점수', axis=1, ascending=*****).iloc[:, :3]
buddy_group_top3.head(len(buddy_group)+1)
# Out:
#           (교촌) 허니콤보  (BBQ) 황금올리브 (푸라닭) 청양마요
# 평균 평가 점수       4.75         4.75        4.5
# 김유진            5.00         5.00          5
# 박세훈            5.00         5.00          5
# 송상훈            4.00         4.00          4
# 허진             5.00         5.00          4
